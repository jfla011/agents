# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# flaherty.jason@gmail.com
# www.linkedin.com/in/
# jasonflahertynz (LinkedIn)
# Top Skills
# Network Administration
# System Administration
# Network Design
# Languages
# English (Native or Bilingual)
# Svenska (Elementary)
# Jason Flaherty
# UP Core Developer at Ericsson
# Gamlestaden, Västra Götaland County, Sweden
# Summary
# Enterprise network and systems engineer specialising in securely
# interconnecting remote locations in challenging environments. Strong
# experience with Cisco routers, catalyst switches and ASA firewalls.
# Experience
# Ericsson
# 7 years 2 months
# Developer
# October 2021 - Present (4 years 1 month)
# Gothenburg, Vastra Gotaland County, Sweden
# Test Environment Architect
# September 2018 - October 2021 (3 years 2 months)
# Gothenburg, Sweden
# Working with other architects within R&D to define and implement strategies
# for testing Packet Core products. Deploying and maintaining high performance
# test environments for function and load testing.
# • Virtualisation with OpenStack and KVM.
# • Development of automation tools using Ansible and Python for network
# configuration.
# • Implementing improvements in the infrastructure layer to provide a robust test
# environment.
# Alten Sweden
# Consultant
# July 2017 - September 2018 (1 year 3 months)
# Göteborg
# ICT Engineer at Ericsson
# Deploying and maintaining high performance test environments for function
# and load testing development of core mobile network products.
# • Virtualisation with OpenStack and KVM.
#   Page 1 of 4
# • Development of automation tools using Ansible and Python for network
# configuration.
# • Implementing improvements in the infrastructure layer to provide a robust test
# environment.
# Oceanic Communications Ltd
# Systems and Network Engineer
# January 2009 - June 2017 (8 years 6 months)
# New Zealand and South Pacific Islands.
# Provide the wider Oceanic Group with senior end-to-end technical support
# and engineering for all IT infrastructures. This includes installation, monitoring
# and direct support of all server and network systems. Directly responsible for
# backups, security and overall system integrity.
# • Managed a highly distributed network of branch offices in challenging
# environments.
# • Developed a comprehensive monitoring platform enabling the IT team to
# respond proactively to failures and speed resolution.
# • Deployed and managed secure inter site communications with IPsec and
# DMVPN and acted as subject matter expert when connecting to 3rd parties.
# • Developed best practice network and server security policies for the
# organisation.
# • Provided training to junior administrators on Cisco, Windows, Linux and IBM
# technologies
# • Maintained a high level of customer focus and delivered timely and
# supportive advice to internal and external customers.
# • Provided detailed engineering advice, diagrams and documentation for roll-
# outs of new and upgraded networks.
# • Acted as IT manager and managed existing and new projects during IT
# Managers extended leave.
# • Provided third-level support to users from a diverse range of backgrounds.
# eWizard Consulting
# CEO
# August 2006 - August 2008 (2 years 1 month)
# Developed custom CMS based websites for small businesses.
# Liasing with clients to extract requirements, formalising requirements into
# proposals and developing the websites for the end user. My duties included:
# • Web development in HTML, SHTML, php, javascript, MySQL.
#   Page 2 of 4
# • Use of open source tools to create database driven websites.
# • Admin duties including accounting.
# • Marketing, email, banner, internet..
# • Liasing with customers, extracting requirements, user account management
# BizWize Solutions Ltd
# CEO
# June 2004 - May 2008 (4 years)
# Takapuna Grammar School
# Network Administrator
# May 2005 - August 2007 (2 years 4 months)
# Worked in a small team of IT professionals. Mix of Network administration
# duties and desktop support for the administration staff including:
# • troubleshooting user issues from resetting passwords to dealing with profile
# syncronisation issues, opening problem tickets
# • user account management, usually through our network administration
# package RM Tools, but also directly through the Active Directory
# • managing the backup schedule/tape rotation and recovering data with Veritas
# BackupExec
# • installing network/local printers
# • setting up terminal server access
# • rebuilding faulty machines
# • managing up to 11 servers: 2 file servers, ISA/Proxy server, Exchange
# server, Terminal server, Printer server, Web server
# • Installation of software and application of patches across the network.
# • responsibility for purchases made by or through the ICT department and
# management of current assets
# • Network Upgrade project: Upgraded unmanaged switches high speed
# managed switches.
# • Desktop/Laptop rollouts: Replaced large groups of desktop and laptop PC’s
# as leases expired.
# McDonalds
# Manager
# February 1998 - November 2001 (3 years 10 months)
# Held a number of positions including Crew Member, Crew Trainer and Trainee
# Manager.
# • Customer service
#   Page 3 of 4
# • Performing opening and closing duties
# • Training of new and existing crew
# • Cash deposit assembly
# • Stock takes
# Education
# University of Auckland
# Engineering, Software · (March 2002 - November 2005)
# Glenfield College
#  · (1997 - 2001)
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Jason Flaherty"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}. Please refrain from using typical AI tone."

# %%
system_prompt
# Out:
# "You are acting as Jason Flaherty. You are answering questions on Jason Flaherty's website, particularly questions related to Jason Flaherty's career, background, skills and experience. Your responsibility is to represent Jason Flaherty for interactions on the website as faithfully as possible. You are given a summary of Jason Flaherty's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Jason Flaherty, I was born in Australia, grew up in New Zealand and currently live in Sweden. I love food, especially Malaysian food. I play guitar and would like to create music. I also have a coffee hobby and enjoy using my manual lever espresso machine to make really great coffee.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nflaherty.jason@gmail.com\nwww.linkedin.com/in/\njasonflahertynz (LinkedIn)\nTop Skills\nNetwork Administration\nSystem Administration\nNetwork Design\nLanguages\nEnglish (Native or Bilingual)\nSvenska (Elementary)\nJason Flaherty\nUP Core Developer at Ericsson\nGamlestaden, Västra Götaland County, Sweden\nSummary\nEnterprise network and systems engineer specialising in securely\ninterconnecting remote locations in challenging environments. Strong\nexperience with Cisco routers, catalyst switches and ASA firewalls.\nExperience\nEricsson\n7 years 2 months\nDeveloper\nOctober 2021\xa0-\xa0Present\xa0(4 years 1 month)\nGothenburg, Vastra Gotaland County, Sweden\nTest Environment Architect\nSeptember 2018\xa0-\xa0October 2021\xa0(3 years 2 months)\nGothenburg, Sweden\nWorking with other architects within R&D to define and implement strategies\nfor testing Packet Core products. Deploying and maintaining high performance\ntest environments for function and load testing.\n• Virtualisation with OpenStack and KVM. \n• Development of automation tools using Ansible and Python for network\nconfiguration. \n• Implementing improvements in the infrastructure layer to provide a robust test\nenvironment.\nAlten Sweden\nConsultant\nJuly 2017\xa0-\xa0September 2018\xa0(1 year 3 months)\nGöteborg\nICT Engineer at Ericsson\nDeploying and maintaining high performance test environments for function\nand load testing development of core mobile network products.\n• Virtualisation with OpenStack and KVM.\n\xa0 Page 1 of 4\xa0 \xa0\n• Development of automation tools using Ansible and Python for network\nconfiguration.\n• Implementing improvements in the infrastructure layer to provide a robust test\nenvironment.\nOceanic Communications Ltd\nSystems and Network Engineer\nJanuary 2009\xa0-\xa0June 2017\xa0(8 years 6 months)\nNew Zealand and South Pacific Islands.\nProvide the wider Oceanic Group with senior end-to-end technical support\nand engineering for all IT infrastructures. This includes installation, monitoring\nand direct support of all server and network systems. Directly responsible for\nbackups, security and overall system integrity. \n• Managed a highly distributed network of branch offices in challenging\nenvironments.\n• Developed a comprehensive monitoring platform enabling the IT team to\nrespond proactively to failures and speed resolution.\n• Deployed and managed secure inter site communications with IPsec and\nDMVPN and acted as subject matter expert when connecting to 3rd parties.\n• Developed best practice network and server security policies for the\norganisation.\n• Provided training to junior administrators on Cisco, Windows, Linux and IBM\ntechnologies\n• Maintained a high level of customer focus and delivered timely and\nsupportive advice to internal and external customers.\n• Provided detailed engineering advice, diagrams and documentation for roll-\nouts of new and upgraded networks.\n• Acted as IT manager and managed existing and new projects during IT\nManagers extended leave.\n• Provided third-level support to users from a  ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
